# %%
#KERNEL DENSITY ESTIMATION PLOTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars=sns.load_dataset('mpg')
cars.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
#To make a kde plot of horsepower
sns.kdeplot(cars.horsepower)
# Out:
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
#To shade the area under the kde plot
sns.kdeplot(cars.horsepower,fill=True)
# Out:
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
#To change the bandwidth of the kde plot
sns.kdeplot(cars.horsepower,bw_adjust=1) #increasing the bandwidth smoothens the curve,while decreasing it increases the number of peaks
plt.show()                               #default bw=0.5
import ipywidgets as widgets
def bandwidth_widget(bw=0.5):
    sns.kdeplot(cars.horsepower,lw=3,fill=True,bw_adjust=bw)
    plt.xlim=(0,250)
    plt.ylim=(0,0.016)
    
widgets.interact(bandwidth_widget,bw=(0.1,3)) #here 0.1 is the minimum value of the slider, and 3 is the maximum value that the slider can take.
                                              #Also, since this is a float slider, the default step is 0.1, but that can be changed
# Out:
# interactive(children=(FloatSlider(value=0.5, description='bw', max=3.0, min=0.1), Output()), _dom_classes=('wi…
# <function __main__.bandwidth_widget(bw=0.5)>

# %%
#BIVARIATE KDE PLOTS
#To plot a kde plot between 2 series of a data

sns.kdeplot(cars.horsepower,cars.mpg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\vinay\OneDrive\Desktop\PYTHON\10.MATPLOTLIB\5.KDEplots.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/vinay/OneDrive/Desktop/PYTHON/10.MATPLOTLIB/5.KDEplots.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> #BIVARIATE KDE PLOTS
#       <a href='vscode-notebook-cell:/c%3A/Users/vinay/OneDrive/Desktop/PYTHON/10.MATPLOTLIB/5.KDEplots.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> #To plot a kde plot between 2 series of a data
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vinay/OneDrive/Desktop/PYTHON/10.MATPLOTLIB/5.KDEplots.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> sns.kdeplot(cars.horsepower,cars.mpg)
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#To see more rings of the plot and to see a shaded plot
sns.kdeplot(cars.horsepower,cars.mpg,n_levels=20,fill=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 #To see more rings of the plot and to see a shaded plot
# ----> 2 sns.kdeplot(cars.horsepower,cars.mpg,n_levels=20,fill=True)
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
#Also, to see the densities represented by each color
sns.kdeplot(cars.horsepower,cars.mpg,n_levels=20,
            fill=True,
            cbar=True) #cbar stands for color bar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #Also, to see the densities represented by each color
# ----> 2 sns.kdeplot(cars.horsepower,cars.mpg,n_levels=20,
#       3             fill=True,
#       4             cbar=True) #cbar stands for color bar
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 2 keyword-only arguments) were given
