# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns

# %%
x=[10,20,30,40]
y=[0,15,10,25]
plt.plot(x,y)

# %%
#To improve the aesthetics of this figure, we can use seaborn
sns.set()
plt.plot(x,y)

# %%
sns.set_style('dark')
plt.plot(x,y)
