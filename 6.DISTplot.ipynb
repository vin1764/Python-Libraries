# %%
#DISTRIBUTION PLOT
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %%
cars=sns.load_dataset('mpg')
cars.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
#a default distplot consists of a combination of a kde plot and a histogram
sns.distplot(cars.weight)
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_22428\3602370517.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight)
# <Axes: xlabel='weight', ylabel='Density'>

# %%
#To also see the rugplot in the distplot
sns.distplot(cars.weight,rug=True)
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_22428\3817724393.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,rug=True)
# <Axes: xlabel='weight', ylabel='Density'>

# %%
#To change the number of bins in the histogram of the distplot
sns.distplot(cars.weight,bins=20)
plt.show()
#Alternatively,we can also see customised bins by entering a list of bins
sns.distplot(cars.weight,bins=[1500,2000,2500,3500,5200])
plt.show()
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_22428\254906933.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,bins=20)
# C:\Users\vinay\AppData\Local\Temp\ipykernel_22428\254906933.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#To change the transparency of the histogram in the distplot
sns.distplot(cars.weight,kde=False,hist_kws={'alpha':1}) #kde=Faalse hides the kdeplot and show only the histogram
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_22428\4255549711.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,kde=False,hist_kws={'alpha':1}) #kde=Faalse hides the kdeplot and show only the histogram
# <Axes: xlabel='weight'>

# %%
#Types of histograms
sns.distplot(cars.weight,kde=False,hist_kws={'histtype':'step'})
plt.show()
sns.distplot(cars.weight,kde=False,hist_kws={'histtype':'stepfilled'})
plt.show()
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_22428\3251242808.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,kde=False,hist_kws={'histtype':'step'})
# C:\Users\vinay\AppData\Local\Temp\ipykernel_22428\3251242808.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
