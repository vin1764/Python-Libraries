# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl

# %%
#Using the same 2 datapoints
x_train=np.array([1,2])
y_train=np.array([300,500])

# %%
#Cost function: It basically shows the difference between actual house price acc to the datapoints and the price predicted by our model

def compute_cost(x,y,w,b):
    m=len(x)
    
    for i in range(m):
        f_wb=w*x[i]+b
        cost=(f_wb-y[i])**2
        cost_sum=cost_sum+cost
    
    total_cost=(1/(2*m))*cost_sum
    
    return total_cost

# %%
#Plotting f_wb against x(price of house against size of house)  and J_wb against w

plt_intuition(x_train,y_train)
# Out:
# interactive(children=(IntSlider(value=150, description='w', max=400, step=10), Output()), _dom_classes=('widge…

# %% [markdown]
# Here we can notice that cost is minimum for w=200

# %%
#Using a larger dataset
x_train=np.array([1.0,1.7,2.0,2.5,3.0,3.2])
y_train=np.array([250,300,480,430,630,730])

# %%
plt.close('all')
fig,ax,dyn_items=plt_stationary(x_train,y_train)
updater=plt_update_onclick(fig,ax,x_train,y_train,dyn_items)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
